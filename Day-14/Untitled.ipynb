# %% [markdown]
# ### Seaborn Library of Matplotlib
#     - Seaborn is a data visualization library in Matplotlib that provides high level interface for creating interactive and more colorful plots with less code.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
palette=sns.color_palette()
print(palette)
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765), (1.0, 0.4980392156862745, 0.054901960784313725), (0.17254901960784313, 0.6274509803921569, 0.17254901960784313), (0.8392156862745098, 0.15294117647058825, 0.1568627450980392), (0.5803921568627451, 0.403921568627451, 0.7411764705882353), (0.5490196078431373, 0.33725490196078434, 0.29411764705882354), (0.8901960784313725, 0.4666666666666667, 0.7607843137254902), (0.4980392156862745, 0.4980392156862745, 0.4980392156862745), (0.7372549019607844, 0.7411764705882353, 0.13333333333333333), (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.palplot(palette)

# %%
palette_green=sns.color_palette('Greens',20)
sns.palplot(palette_green)

# %%
data_dict = {
    'building': ('Burj Khalifa', 'Merdeka 118', 'Effeil Tower'),
    'building_height': [150, 120, 100]
}

bar_colors=['red','geen','yellow']  # Fixed: replaced period with comma
data = pd.DataFrame(data_dict)
sns.barplot(x='building', y='building_height', data=data, hue='category',palette=bar_colors)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 8
#       6 bar_colors=['red','geen','yellow']  # Fixed: replaced period with comma
#       7 data = pd.DataFrame(data_dict)
# ----> 8 sns.barplot(x='building', y='building_height', data=data, hue='category',palette=bar_colors)
#       9 plt.show()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:2341, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2338 if estimator is len:
#    2339     estimator = "size"
# -> 2341 p = _CategoricalAggPlotter(
#    2342     data=data,
#    2343     variables=dict(x=x, y=y, hue=hue, units=units, weight=weights),
# ...
